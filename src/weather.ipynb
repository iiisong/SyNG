# %%
import pandas as pd
from utils import plot_drift, dataset_to_df, df_to_dataset
from evals import eval_classifier

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from river import ensemble
from river import evaluate
from river import linear_model
from river import metrics
from river import optim, utils
from river import preprocessing

# %%
weather_data = pd.read_csv("../data/weather/NEweather_data.csv", header=None)
weather_class = pd.read_csv("../data/weather/NEweather_class.csv", names=["value"])

# %%
df = pd.concat([weather_data, weather_class], axis=1)

# %%
display(df)
# Out:
#           0     1       2    3     4     5     6     7  value
# 0      19.8  14.0  1019.6  8.4   9.9  15.9  28.9  14.0      0
# 1      26.8  22.2  1006.2  8.1  10.9  19.0  34.0  21.0      0
# 2      34.6  32.9  1004.6  3.9  13.8  22.0  36.0  33.1      1
# 3      26.4  21.5  1006.9  8.0  18.7  30.1  39.9  16.0      1
# 4      14.7   7.9  1009.9  8.1  14.1  22.0  21.0   9.0      0
# ...     ...   ...     ...  ...   ...   ...   ...   ...    ...
# 18154  32.6  21.9  1022.7  7.0  12.4  26.0  41.0  24.8      1
# 18155  36.8  25.4  1014.9  7.0  10.0  19.0  57.2  21.2      0
# 18156  41.9  29.9  1010.0  7.0   4.7   9.9  62.6  28.4      0
# 18157  42.4  29.7  1011.3  7.0   3.3   8.9  51.8  32.0      0
# 18158  36.6  29.5  1017.9  6.8   4.8  13.0  53.6  24.8      0
#
# [18159 rows x 9 columns]

# %%
print("Weather Prediction (Overall | Rolling)")
eval_classifier(df_to_dataset(df))
# Out:
# Weather Prediction (Overall | Rolling)
# plain: Accuracy: 72.58% | Accuracy: 85.00%
# Ada: Accuracy: 73.98% | Accuracy: 88.00%
# ADWIN: Accuracy: 73.40% | Accuracy: 84.00%
