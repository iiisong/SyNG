# %% [markdown]
# SDV using hard coded dataset

# %%
# %pip install sdv
from sdv.single_table import GaussianCopulaSynthesizer
from sdv.metadata import SingleTableMetadata
import pandas as pd

# Sample real dataset
data = pd.DataFrame({
    'age': [25, 30, 45, 35, 50, 23, 40],
    'income': [50000, 60000, 80000, 75000, 120000, 45000, 70000],
    'purchases': [5, 7, 9, 6, 12, 3, 8]
})

# Create metadata for the dataset
metadata = SingleTableMetadata()
metadata.visualize()
metadata.detect_from_dataframe(data)

# Initialize and fit the synthesizer
synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(data)

# Generate synthetic data
synthetic_data = synthesizer.sample(100)
print(synthetic_data)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.1/156.1 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 59.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# SDV using demo dataset

# %%
# %pip install sdv

from sdv.datasets.demo import download_demo
from sdv.single_table import GaussianCopulaSynthesizer

real_data, metadata = download_demo(
    modality='single_table',
    dataset_name='fake_hotel_guests'
)
synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(real_data)

metadata.visualize()

synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.fit(real_data)
synthetic_data = synthesizer.sample(100)
print(synthetic_data)
# Out:
# ...
#                      guest_email  has_rewards room_type  amenities_fee  \
# 0          dsullivan@example.net        False     BASIC           0.29
# 1           steven59@example.org        False    DELUXE           8.15
# 2          brandon15@example.net        False     BASIC          11.65
# 3   humphreyjennifer@example.net        False     BASIC          48.12
# 4        joshuabrown@example.net        False    DELUXE          11.07
# ..                           ...          ...       ...            ...
# 95       lynnjohnson@example.org         True    DELUXE           0.19
# 96           omartin@example.org        False     BASIC          15.45
# 97  meghanharrington@example.com        False     BASIC          48.12
# 98         garydavid@example.net        False     BASIC          10.82
# 99           emily36@example.com        False     BASIC           8.36
#
#    checkin_date checkout_date  room_rate  \
# 0   27 Mar 2020   09 Mar 2020     135.15
# ...

# %% [markdown]
# # SDV Using imported csv from FNC Dataset
# Ways to import data: https://www.geeksforgeeks.org/ways-to-import-csv-files-in-google-colab/

# %%
from google.colab import files
import pandas as pd
import io
uploaded = files.upload()
df = pd.read_csv('1-2020.csv')
print(df)
# Out:
#      Unnamed: 0                                               text  label  \
# 0         27128  State broadcaster China Central Television ann...      0
# 1         51116  The city of Lone Tree asked residents to avoid...      1
# 2         19487  According to a manager at a store in the Penns...      0
# 3         12607  About 6:50 p.m. , about five to six males wear...      1
# 4         75678  Netflix has treated fans to a sneaky look at t...      1
# ..          ...                                                ...    ...
# 764       46794  • 106 people have died from a coronavirus outb...      1
# 765       46795  • China is using drones to scold people for wa...      1
# 766       46796  • The Dow erases January gains in the last day...      1
# 767         745  It ’ s not unusual to see Asian tourists weari...      1
# 768       84152  Russia has registered its first two cases of c...      1
#
#     timestamp
# 0      1-2020
# 1      1-2020
# 2      1-2020
# 3      1-2020
# ...
